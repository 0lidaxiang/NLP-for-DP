# %%
# %%time
import pandas as pd
from gensim.models.word2vec import Word2Vec

train_df = pd.read_pickle("./train.pkl")
test_df = pd.read_pickle("./test.pkl")
train_df.head()

corpus = pd.concat([train_df.text, test_df.text]).sample(frac=1)
corpus.head()

model = Word2Vec(corpus, size=250, iter= 8, workers=3, min_count=5, negative=3, max_vocab_size=None, window=5)

model_file_name = 'word2vec_20180425.model'
model.save(model_file_name)
model = Word2Vec.load(model_file_name)
# Out:
# CPU times: user 1min 10s, sys: 576 ms, total: 1min 11s
# Wall time: 27.9 s

# %%
def most_similar(w2v_model, words, topn=10):
    similar_df = pd.DataFrame()
    for word in words:
        try:
            similar_words = pd.DataFrame(w2v_model.wv.most_similar(word, topn=topn), columns=[word, 'cos'])
            similar_df = pd.concat([similar_df, similar_words], axis=1)
        except:
            print(word, "not found in Word2Vec model!")
    return similar_df

# %%
res = model.most_similar("日本", topn=100)

print("日本")
print("相似詞前 100 排序:")

for v in res:
    print(v[0], ",", v[1])

print('\r\n\n')

res1 = model.similarity('日本', '台灣')
print('日本', '台灣 : ', res1)
# Out:
# 日本
# 相似詞前 100 排序:
# 當地 , 0.748627781867981
# 圓夢而 , 0.7470744252204895
# 自助 , 0.7138994336128235
# 物價來 , 0.7074791789054871
# 滿山 , 0.6864652037620544
# 享樂 , 0.6852779984474182
# 環島 , 0.6820868849754333
# 台湾 , 0.678985595703125
# 繩 , 0.6789830923080444
# 肯德基 , 0.677454948425293
# 最東 , 0.6765496730804443
# 重機 , 0.6764671802520752
# 台灣 , 0.6756898760795593
# 各地 , 0.6598824262619019
# 走遍 , 0.6547013521194458
# 闖 , 0.6512263417243958
# 賞櫻 , 0.6495187282562256
# 旅遊 , 0.649223804473877
# 旅行 , 0.6452166438102722
# 三景 , 0.6415303349494934
# 神遊 , 0.6397138833999634
# 本島 , 0.6395944356918335
# 最北 , 0.6356479525566101
# 去過 , 0.6350236535072327
# 京都 , 0.6341726183891296
# 東京 , 0.6339036822319031
# 說裡面 , 0.6301803588867188
# 街頭 , 0.6298992037773132
# 職棒 , 0.6298618912696838
# 花季 , 0.6289377212524414
# 相挺 , 0.6277396082878113
# 大阪 , 0.6262158751487732
# 人開 , 0.6260285377502441
# 橋稅務署 , 0.6202307343482971
# 選在 , 0.6172453165054321
# 北海道 , 0.6169175505638123
# 時節 , 0.6168146729469299
# 歐吉桑 , 0.6126484274864197
# 觀光客 , 0.6111941337585449
# 鄭州 , 0.6111796498298645
# 人習 , 0.6099593043327332
# 回訪 , 0.6096453070640564
# 十一天 , 0.6091879606246948
# 香港 , 0.6090716123580933
# 此行 , 0.6082310676574707
# 限定 , 0.6056843400001526
# 團來 , 0.6043668389320374
# 必訪 , 0.6030232906341553
# 而勇 , 0.6023284196853638
# 四十七 , 0.6012387871742249
# 行 , 0.6005162000656128
# 季節 , 0.6001968383789062
# 迪士尼 , 0.5985048413276672
# 肉店 , 0.5957876443862915
# 祈願 , 0.5956628322601318
# 大都市 , 0.5943379402160645
# 特產 , 0.5938351154327393
# 三大 , 0.5937610864639282
# 必吃 , 0.590689480304718
# 方方 , 0.5885171294212341
# 寺廟 , 0.5879868268966675
# 春櫻 , 0.5876320004463196
# 自由 , 0.5869893431663513
# 櫻名 , 0.5856128931045532
# 落葉 , 0.5841690897941589
# 分店 , 0.5837764739990234
# 這裡 , 0.5819121599197388
# 奢侈 , 0.5815079808235168
# ﾟ , 0.581335723400116
# 美食 , 0.5813238620758057
# 北極星 , 0.5796353816986084
# 311 , 0.5780964493751526
# 台灣時 , 0.578005850315094
# 古都 , 0.5770140290260315
# 旅行者 , 0.5759844779968262
# 阿根廷 , 0.5758088827133179
# 私房 , 0.5744185447692871
# 紀念品 , 0.5740841627120972
# 帶回 , 0.5739467740058899
# 攤販 , 0.5731284022331238
# 聖誕節 , 0.5703544020652771
# 地陪 , 0.5696835517883301
# 咖啡店 , 0.5695207715034485
# 老店 , 0.5680184364318848
# 好多好多 , 0.5674333572387695
# 名店 , 0.5669898390769958
# 做給 , 0.5669094920158386
# 造訪 , 0.5658828616142273
# 必去 , 0.5651249885559082
# 文殊 , 0.5651220083236694
# 古著店 , 0.5641713738441467
# 旅遊書 , 0.5632374882698059
# 威尼斯 , 0.562675416469574
# 之旅 , 0.5620145201683044
# 這趟 , 0.5615295171737671
# 連鎖 , 0.5614919066429138
# 駕車 , 0.5609622001647949
# 錯過 , 0.560336709022522
# 整趟 , 0.5597332715988159
# 三月底 , 0.5589805245399475
#
#
#
# 日本 台灣 :  0.6756898019130748
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
# model = Word2Vec(corpus, size=250, iter= 8(不能擴到20), workers=3, min_count=5, negative=3, max_vocab_size=None, window=5)
# most_similar(model, ['懷孕', '網拍', '補習', '東京', 'XDD', '金宇彬','化妝品', '奧斯卡', '主管', '女孩'])
# Out:
#     懷孕       cos   網拍       cos   補習       cos   東京       cos  XDD       cos  \
# 0  預產期  0.893640   賣場  0.923050    班  0.951525  北海道  0.958461  先感謝  0.867511
# 1    懷  0.889829   買過  0.922617   面授  0.928847   大阪  0.942050  鄉民們  0.861077
# 2  第二胎  0.872642   生火  0.908669   沒補  0.901709   造訪  0.930999  小女子  0.825438
# 3   孕前  0.872387   彤彤  0.903401   戴然  0.899003   賞櫻  0.924640   滅火  0.822599
# 4   出生  0.870882  這雙鞋  0.899040  劉明彰  0.890872   賞梅  0.921439  有板友  0.816242
# 5   到現  0.861759   贈品  0.895891   先修  0.888846   關西  0.913134   版友  0.815478
# 6   生病  0.860793   韓貨  0.895393    課  0.885557   近郊  0.907619   女板  0.813170
# 7    孕  0.860671  淘寶的  0.893052   正課  0.884413   京都  0.905862  媽寶版  0.811990
# 8  第一胎  0.859393   似款  0.892573  郭老師  0.875848  天滿宮  0.903625   很亂  0.811179
# 9   大寶  0.858508   牌子  0.891527   題庫  0.874726  城公園  0.901634   文有  0.810674
#
#    金宇彬       cos  化妝品       cos   奧斯卡       cos  主管       cos   女孩       cos
# 6   李玟  0.921495   櫃上  0.856499  執導  0.946922  開會  0.796486    惹  0.673248
# 7   道士  0.921222   試用  0.853340  暫譯  0.946827  無聲  0.793811  朋友圈  0.670901
# 8   銀赫  0.921211   這瓶  0.849615  喜劇  0.943872  試時  0.790615   阿為  0.670753
# 9  姜鎬童  0.920282   回購  0.849439  影壇  0.943223  組長  0.784436   帥氣  0.666096

# %%
# model = Word2Vec(corpus, size=250, iter= 10, workers=3, min_count=5, negative=5, max_vocab_size=None, window=5)
# most_similar(model, ['懷孕', '網拍', '補習', '東京', 'XDD', '金宇彬','化妝品', '奧斯卡', '主管', '女孩'])
# Out:
#     懷孕       cos   網拍       cos   補習       cos   東京       cos   XDD       cos  \
# 0    懷  0.888186   韓貨  0.871836    班  0.894504  北海道  0.893725   小女子  0.854312
# 1  第一胎  0.868165   商城  0.867707   班教  0.852149   淺草  0.881905   先感謝  0.839020
# 2  第二胎  0.855265   彤彤  0.861366   面授  0.850377   賞櫻  0.874388    多謝  0.834938
# 3   胃炎  0.840987   賣場  0.860783   題庫  0.818063   造訪  0.872593  300P  0.833986
# 4   孕前  0.839764   買過  0.852900   補過  0.814522   大阪  0.863464   違反版  0.830951
# 5   住院  0.831355  淘寶的  0.851168  考資工  0.808036   之旅  0.861995   研所版  0.830840
# 6   生病  0.826639  類似款  0.841573  郭老師  0.804055   此行  0.856043    文想  0.830265
# 7   寶寶  0.820830   生火  0.835089   正課  0.800416  名古屋  0.838709    文有  0.828923
# 8   出生  0.815210   同款  0.835004   大三  0.799209   札幌  0.838011    轉貼  0.827226
# 9  預產期  0.814842  這雙鞋  0.828333   補帶  0.798501   關西  0.836615    答謝  0.824452
#
#    金宇彬       cos  化妝品       cos 奧斯卡       cos  主管       cos  女孩       cos
# 0  李鍾碩  0.961223   專櫃  0.896443  影帝  0.957847  面談  0.861514  美女  0.690605
# 1  金秀路  0.941846  保養品  0.893107  提名  0.957809   談  0.828533  女生  0.671822
# 2  朴明洙  0.941310   開架  0.874496  主演  0.953652  人資  0.823869  兒們  0.669924
# 3   笑星  0.935222   好物  0.844273  新作  0.950009  面試  0.811996  男生  0.660242
# 4   天命  0.934712  化妝包  0.843402  派克  0.947139  口頭  0.792100  女人  0.654867
# 5   姜虎  0.933703   櫃上  0.842812  執導  0.945756  獵頭  0.781632   兒  0.653457
# 6   跳水  0.927295   試用  0.841424  德利  0.944391  開會  0.775399   惹  0.644093
# 7  尹鍾信  0.927011   添購  0.841287   獎  0.943624  離職  0.766505  正妹  0.642844
# 8    泫  0.926674   手邊  0.839095  新片  0.939866  試時  0.761889  打扮  0.641704
# 9   演藝  0.924490   回購  0.827175  戰記  0.939270  無聲  0.761779  妹妹  0.637220

# %%
# %%time
# res = model.most_similar("日本", topn=100)

# print("日本")
# print("相似詞前 100 排序:")

# for v in res:
#     print(v[0], ",", v[1])

# print('\r\n\n')

# res1 = model.similarity('日本', '台灣')
# print('日本', '台灣 : ', res1)
